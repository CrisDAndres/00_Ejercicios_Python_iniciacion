# %% [markdown]
# # Python Crash Course Ejercicios

# %% [markdown]
# ## Miscelánea

# %% [markdown]
# **Calcule 7 elevado a 4**

# %%
7**4
# Out:
# 2401

# %% [markdown]
# *Resultado esperado:*
#
# ```python
# 2401
# ```

# %% [markdown]
# **Divida el siguiente string en una lista**
# ```python
# s = 'Hi there, Sam!'
# ```

# %%
s = "Hi there, Sam!"
# Para ello utilizaremos la función split() y le indicaremos que lo separe en 3 elementos que estén delimitados por espacios
s.split()
# Out:
# ['Hi', 'there,', 'Sam!']

# %% [markdown]
# *Resultado esperado:*
#
# ```python
# ['Hi', 'there,', 'Sam!']
# ```

# %% [markdown]
# **Dadas las variables**
#
#     planet = "Earth"
#     diameter = 12742
#
# **use el método .format() para imprimir el siguiente string:**
# ```python
# 'The diameter of Earth is 12742 kilometers.'
# ```

# %%
planet = "Earth"
diameter = 12742
print("The diameter of {} is {} kilometers".format(planet,diameter))
# Out:
# The diameter of Earth is 12742 kilometers

# %% [markdown]
# **Dada la siguiente lista concatenada, obtenga de la misma el string 'hello':**
#
# ```python
# lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]
# ```

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]
# El string 'hello' forma parte del cuarto elemento de la lista, que es otra lista
# Primero tendremos que acceder a ese cuarto elemento (3, porque empieza por 0)
# Dentro de ese elemento o lista, forma parte del segundo elemento (1), que es otra lista
# Por último, dentro de esa última lista, es el tercer elemento (2)
lst[3][1][2]
# También se podría poner lst[3][1][-1], porque hello estça en última posición
# Out:
# ['hello']

# %% [markdown]
# **Dado este diccionario concatenado**
#
# ```python
# d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}
# ```
# **obtenga el string 'hello':**

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# el str hello forma parte de un valor. Podemos acceder a él utilizando su clave, que sería target
# la clave target forma parte del valor de la primera clave k1:
valores_k1 = d["k1"]
valores_k1
# Out:
# [1,
#  2,
#  3,
#  {'tricky': ['oh', 'man', 'inception', {'target': [1, 2, 3, 'hello']}]}]

# %%
# Como vemos, la clave target forma parte del cuarto valor de k1. Para acceder a él:
valor4_k1 = valores_k1[3]
valor4_k1
# Out:
# {'tricky': ['oh', 'man', 'inception', {'target': [1, 2, 3, 'hello']}]}

# %%
# Dentro del cuarto valor de k1, la clave target forma parte del valor tricky. Para acceder a él:
valores_tricky = valor4_k1["tricky"]
valores_tricky
# Out:
# ['oh', 'man', 'inception', {'target': [1, 2, 3, 'hello']}]

# %%
# La clave target es el cuarto elemento de la lista de valores. Para acceder:
clave_target = valores_tricky[3] 
clave_target
# Out:
# {'target': [1, 2, 3, 'hello']}

# %%
# hello es el cuarto valor de la clave target:
valores_target = clave_target["target"]
valores_target
resultado= valores_target[3]
resultado
# Out:
# 'hello'

# %%
# Uniendo todo, el resultado para imprimir "hello" del diccionario 'd' sería el siguiente:
# d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}
resultado = d["k1"][3]["tricky"][3]["target"][3]
resultado
# Otra opción d["k1"][-1]["tricky"][3]["target"][-1]
# Out:
# 'hello'

# %% [markdown]
# **Implemente una función llamada domainGet que obtenga el dominio del email de un usuario. Por ejemplo, para el correo**
# ```
#     user@domain.com
# ```
# **se desprendería 'domain.com'. Compruebe el resultado con este propio email.**

# %%
def domainGet(email):
    dominio = email.split('@')[-1]
    return dominio

domainGet("user@domain.com")
# Out:
# 'user'

# %%
# otra opción

domainGet = lambda mail:mail.split('@')[-1]

domainGet("user@domain.com")
# Out:
# 'domain.com'

# %% [markdown]
# **Implemente una función llamada findDog, que tenga como entrada un string, que devuelva el valor True si ese string contiene la palabra 'dog'. Tenga en cuenta las posibles mayúsculas, y compruebe su función con el string 'Is there a dog here?'.**

# %%
def findDog(str):
    str = str.lower()
    if "dog" in str:  # Con el operador in buscamos una subcadena dentro de otra
        return True
    else:
        return False
findDog("Is there a dog here?")
# Out:
# True

# %%
# Otra opcion

findDog = lambda frase : 'dog' in frase.lower()
findDog("Is there a dog here?")
# Out:
# True

# %% [markdown]
# **Implemente una función similar a la del ejercicio anterior, pero que esta vez cuente el número de apariciones del string 'dog' en un cierto input. Compruebe sus resultados con el string:**
#
# ```python
# 'This dog runs faster than the other dog dude!'
# ```

# %%
def countingDog(str):
    str = str.lower()
    new_str=str.split() # Primero hay que dividir la cadena en las diferentes palabras y asignar la nueva cadena a una nueva variable, sino el operador for operará por cada letra
    dog = 0
    for palabra in new_str:
    
        if palabra == "dog":
            dog+=1
    return dog
        
countingDog("This dog runs faster than the other dog dude!")
# Out:
# 2

# %%
# Otra opcion

countingDog = lambda frase : frase.lower().count('dog')
countingDog("This dog runs faster than the other dog dude!")
# Out:
# 2

# %% [markdown]
# **Use funciones lambda y la función .filter() para filtrar palabras de una lista que no empiecen con la letra 's'. Por ejemplo,**
# ```python
# seq = ['soup','dog','salad','cat','great']
# ```
#
# **debería ser filtrado para obtener:**
# ```python
# seq = ['soup','salad']
# ```

# %%
seq = ['soup','dog','salad','cat','great']

no_s = list(filter(lambda item:item[0]=="s",seq)) # Me quedo con las palabras cuyo primer item (o letra) sea 's', y lo convierto en lista, porque sino sería string por defecto
no_s
# Out:
# ['soup', 'salad']

# %% [markdown]
# ## Métodos (I)
# Un conductor va a una velocidad demasiado rápida, y un agente le detiene. Escribe una función con tres posibles resultados, *no ticket*, *small ticket* o *big ticket*, y que devuelva lo siguiente:
#
# *  Si la velocidad es de 60 o menos, el resultado debe ser *no ticket*.
# *  Si la velocidad está entre 61 y 80 (inclusive), el resultado debe ser *small ticket*.
# *  Si la velocidad es superior a 80, el resultado debe ser *big ticket*.
# *  Si es tu cumpleaños, puedes ir a la velocidad que quieras.

# %%
def caught_speeding(speed, is_birthday):
    if is_birthday==True:
        print("Happy birthday! No ticket")
    elif speed <= 60:
        print("No ticket")
    elif speed > 61 and speed <= 80:
        print("Small ticket")
    else: 
        print("big ticket")

# %%
# Otra manera

def caught_speeding(speed, is_birthday):
    if is_birthday or speed <= 60:
        print("No ticket")
    
    elif speed > 61 and speed <= 80:
        print("Small ticket")
    else: 
        print("big ticket")

# %%
caught_speeding(81,True)
# Out:
# No ticket

# %%
caught_speeding(81,False)
# Out:
# big ticket

# %% [markdown]
# # Clases (I)
# Realizar un programa que conste de una clase llamada Alumno que tenga como atributos el nombre y la(s) nota(s) del alumno en una lista. Definir los métodos para inicializar sus atributos, imprimirlos y mostrar un mensaje con el resultado de la nota y si ha aprobado o no.
#
# *Indicaciones: Para inicializar la clase, directamente podemos introducir la media de las notas:*
#
# ```python
# # inicializamos la clase
# class Alumno:
#     # inicializamos los atributos
#     def __init__(self,nombre,notas):
#         self.nombre=nombre
#         self.nota_media=sum(notas)*1.0/len(notas) # ¿Por qué multiplicar por 1.0?
# ```
#
# *Tras este paso, habrá que incluir en la clase un par de métodos para imprimir parámetros y mostrar el resultado de la evaluación. Expendiendo esta sección, encontrarás la solución del problema, intenta antes hacerlo por ti mismo y comparar los resultados.*

# %%
class Alumno:
    
    def __init__(self,nombre,notas):
        self.nombre=nombre
        self.nota_media=sum(notas)*1.0/len(notas)
        
    # Función para imprimir los parámetros
    def imprimir_parametros(self):
        print(f"Nombre:{self.nombre}\nNota media:{self.nota_media}")
        
    # Función para obtener la evaluación   
    def evaluacion(self):
        if self.nota_media >= 5:
            print(f"{self.nombre} ha aprobado")
        else:
            print(f"{self.nombre} ha suspendido")

nombre = 'Cristina'
notas = [5,8,2]
mis_notas = Alumno(nombre,notas) # Inicializamos la función principal
mis_notas.imprimir_parametros() # Inicializamos la segunda función
mis_notas.evaluacion() # Inicializamos la tercera función
# Out:
# Nombre:Cristina
# Nota media:5.0
# Cristina ha aprobado

# %% [markdown]
# **Solución:** Los métodos faltantes son:
#
# ```python
#     # función para imprimir los datos
#     def imprimir(self):
#       print("Nombre: ",self.nombre)
#       print("Nota media: ",self.nota_media)
#
#
#     # función para obtener el resultado
#     def resultado(self):
#       if self.nota_media < 5:
#         print("El alumno ha suspendido")
#       else:
#         print("El alumno ha aprobado")
# ```
#
# Ahora probamos el código con un ejemplo:

# %%
#Parámetros
nombre = 'Ambrosio'
notas = [6,8,4]
#Clase
# inicializamos la clase
class Alumno:
    # inicializamos los atributos
    def __init__(self,nombre,notas):
        self.nombre=nombre
        self.nota_media=sum(notas)*1.0/len(notas) # ¿Por qué multiplicar por 1.0?
    # función para imprimir los datos
    def imprimir(self):
      print("Nombre: ",self.nombre)
      print("Nota media: ",self.nota_media)
 
    # función para obtener el resultado
    def resultado(self):
      if self.nota_media < 5:
        print("El alumno ha suspendido")
      else:
        print("El alumno ha aprobado")

#Inicializamos
claseNotas = Alumno(nombre, notas)
claseNotas.imprimir()
claseNotas.resultado()
# Out:
# Nombre:  Ambrosio
# Nota media:  6.0
# El alumno ha aprobado

# %% [markdown]
# *Otro ejemplo de clase sería el siguiente:*

# %%
class Estudiante:
    # Función de inicio
    def __init__(self, nombre, edad, curso): # Self que significa la propia clase, lo demás son atributos
        self.nombre = nombre
        self.edad = edad
        self.curso = curso
        
    # Segunda función, hereda de la primera    
    def estudiar(self):
        return f'{self.nombre} está estudiando {self.curso}'
    
    # Tercera función, hereda de la primera
    def cambiar_curso(self, nuevo_curso):
        self.curso = nuevo_curso
        return f'{self.nombre} ha cambiado a {self.curso}'

# %% [markdown]
# # Avanzado: Clases (II)
#
# Realizar una clase que administre una agenda. Se debe almacenar para cada contacto el nombre, el teléfono y el email. Además deberá mostrar un menú con las siguientes opciones:
#
# *  Añadir contacto
# *  Lista de contactos
# *  Buscar contacto
# *  Editar contacto
# *  Cerrar agenda

# %%
class Agenda:
    def __init__(self,nombre,telefono,email):
        self.nombre=nombre
        self.telefono=telefono
        self.email=email
    def menu(self):
        lista_contactos=[]
        nuevo_contacto=input("Añadir contacto: ")
        lista_contactos.append(nuevo_contacto)

# %% [markdown]
# **Solución:**

# %%
# creamos nuestra clase agenda
class Agenda:
	# iniciamos nuestra clase
	def __init__(self):
		# crearemos una lista donde guardaremos los datos de nuestra agenda
		self.contactos=[]
 
	# menu del programa
	def menu(self):
		print()
		menu=[
			['Agenda Personal'],
			['1. Añadir Contacto',"anadir"],
			['2. Lista de contactos'],
			['3. Buscar contacto'],
			['4. Editar contacto'],
			['5. Cerrar agenda']
		]
 
		for x in range(6):
			print(menu[x][0])

		opcion=int(input("Introduzca la opción deseada: "))
		if opcion==1:
			self.anadir()
			self.menu()
		elif opcion==2:
			self.lista()
			self.menu()
		elif opcion==3:
			self.buscar()
			self.menu()
		elif opcion==4:
			self.editar()
			self.menu()
		elif opcion==5:
			print("Saliendo de la agenda ...")
			exit()
 

 
 
	# función para añadir un contacto
	def anadir(self):
		print("---------------------")
		print("Añadir nuevo contacto")
		print("---------------------")
		nom=input("Introduzca el nombre: ")
		telf=int(input("Introduzca el teléfono: "))
		email=input("Introduzca el email: ")
		self.contactos.append({'nombre':nom,'telf':telf,'email':email})
		
	
	# función para imprimir la lista de contactos
	# En este caso imprimiremos solo los nombres de los contactos
	# con ellos podremos buscar luego un contacto
	def lista(self):
		print("------------------")
		print("Lista de contactos")
		print("------------------")
		if len(self.contactos) == 0:
			print("No hay ningún contacto en la agenda")
		else:
			for x in range(len(self.contactos)):
				print(self.contactos[x]['nombre'])
		
	
	# función para buscar un contacto a través del nombre
	def buscar(self):
		print("---------------------")
		print("Buscador de contactos")
		print("---------------------")
		nom=input("Introduzca el nombre del contacto: ")
		for x in range(len(self.contactos)):
			if nom == self.contactos[x]['nombre']:
				print("Datos del contacto")
				print("Nombre: ",self.contactos[x]['nombre'])
				print("Teléfono: ",self.contactos[x]['telf'])
				print("E-mail: ",self.contactos[x]['email'])
				return x
		
	
	
	# función para editar los datos de un contacto
	def editar(self):
		print("---------------")
		print("Editar contacto")
		print("---------------")
		data=self.buscar()
		condition=False
		while condition==False:
			print("Selecciona que quieres editar: ")
			print("1. Nombre")
			print("2. Teléfono")
			print("3. E-mail")
			print("4. Volver")
			option=int(input("Introduzca la opción deseada: "))
			if option==1:
				nom=input("Introduzca el nuevo nombre: ")
				self.contactos[data]['nombre']=nom
			elif option==2:
				telf=input("Introduzca el nuevo teléfono: ")
				self.contactos[data]['telf']=telf
			elif option==3:
				email=input("Introduzca el nuevo email: ")
				self.contactos[data]['email']=email
			elif option==4:
				condition=True

# %%
# bloque principal
agenda=Agenda()
agenda.menu()
# Out:
# Agenda Personal
# 1. Añadir Contacto
# 2. Lista de contactos
# 3. Buscar contacto
# 4. Editar contacto
# 5. Cerrar agenda
# Introduzca la opción deseada: 3
# ---------------------
# Buscador de contactos
# ---------------------
# Introduzca el nombre del contacto: Antonio
# Datos del contacto
# Nombre:  Antonio
# Teléfono:  644752766
# E-mail:  azm630@inlumine.ual.es
